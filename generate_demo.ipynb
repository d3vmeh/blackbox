# %% [markdown]
# # Fuse Breaker — demo UI generator
#
# Run from repo root so `html_outputs/` is created here.
#
# Requires: `pip install anthropic ipython` and `ANTHROPIC_API_KEY` set.

# %%
from html_helpers import generate_html_with_claude
from fuse_breaker_prompts import (
    BASE_SYSTEM_PROMPT,
    DISTILLED_AESTHETICS_PROMPT,
    USER_PROMPT,
)

SYSTEM = BASE_SYSTEM_PROMPT + "\n\n" + DISTILLED_AESTHETICS_PROMPT

filepath = generate_html_with_claude(SYSTEM, USER_PROMPT)
print(f"Done: {filepath}")
